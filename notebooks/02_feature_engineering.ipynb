# %% [markdown]
# # 02: Feature Engineering & Splitting

# %%
import sys, os
sys.path.append(os.path.abspath('..'))

from src.preprocessing import load_data, clean_data
from src.feature_engineering import get_preprocessor, split_data

# %%
df = load_data("../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df = clean_data(df)

# %%
X_train, X_test, y_train, y_test = split_data(df, target_col="Churn")

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)

# %%
preprocessor, num_cols, cat_cols = get_preprocessor()
